# %% [markdown]
# # TASK 4A. IMPORT KEY LIBRARIES & DEFINE KEY FUNCTIONS THAT WILL BE USED IN THE MCP SERVER

# %% [markdown]
# - For this project, we will be using the `gradio` library to build the MCP server.
# - We will be using the `openai` library to interact with the OpenAI API.
# - We will be using the `dotenv` library to load the environment variables.
#
#
#
# What it does:
#
# - It is a server that exposes four powerful learning-oriented tools via the Model-Context-Protocol (MCP).
# - All functions are OpenAI-powered and most stream partial tokens for low-latency UX.

# %%
# Install the packages
# !pip install "gradio[mcp]"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gradio[mcp] in c:\users\waris\appdata\roaming\python\python313\site-packages (6.20.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\programdata\anaconda3\lib\site-packages (from gradio[mcp]) (4.10.0)
# Requirement already satisfied: audioop-lts<=0.2.2 in c:\users\waris\appdata\roaming\python\python313\site-packages (from gradio[mcp]) (0.2.2)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\waris\appdata\roaming\python\python313\site-packages (from gradio[mcp]) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\waris\appdata\roaming\python\python313\site-packages (from gradio[mcp]) (0.138.2)
# Requirement already satisfied: gradio-client==2.5.0 in c:\users\waris\appdata\roaming\python\python313\site-packages (from gradio[mcp]) (2.5.0)
# Requirement already satisfied: groovy~=0.1 in c:\users\waris\appdata\roaming\python\python313\site-packages (from gradio[mcp]) (0.1.2)
# Requirement already satisfied: hf-gradio<1.0,>=0.4.1 in c:\users\waris\appdata\roaming\python\python313\site-packages (from gradio[mcp]) (0.4.1)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\programdata\anaconda3\lib\site-packages (from gradio[mcp]) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=1.2.0 in c:\users\waris\appdata\roaming\python\python313\site-packages (from gradio[mcp]) (1.21.0)
# Requirement already satisfied: jinja2<4.0 in c:\programdata\anaconda3\lib\site-packages (from gradio[mcp]) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\programdata\anaconda3\lib\site-packages (from gradio[mcp]) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from gradio[mcp]) (2.3.5)
# Requirement already satisfied: orjson~=3.0 in c:\users\waris\appdata\roaming\python\python313\site-packages (from gradio[mcp]) (3.11.9)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from gradio[mcp]) (25.0)
# Requirement already satisfied: pandas<4.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from gradio[mcp]) (2.3.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in c:\users\waris\appdata\roaming\python\python313\site-packages (from gradio[mcp]) (12.3.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in c:\users\waris\appdata\roaming\python\python313\site-packages (from gradio[mcp]) (2.12.5)
# Requirement already satisfied: pydub<1.0 in c:\users\waris\appdata\roaming\python\python313\site-packages (from gradio[mcp]) (0.25.1)
# Requirement already satisfied: python-multipart<1.0,>=0.0.18 in c:\users\waris\appdata\roaming\python\python313\site-packages (from gradio[mcp]) (0.0.32)
# Requirement already satisfied: pytz>=2017.2 in c:\programdata\anaconda3\lib\site-packages (from gradio[mcp]) (2025.2)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\programdata\anaconda3\lib\site-packages (from gradio[mcp]) (6.0.3)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in c:\users\waris\appdata\roaming\python\python313\site-packages (from gradio[mcp]) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\waris\appdata\roaming\python\python313\site-packages (from gradio[mcp]) (2.10.0)
# Requirement already satisfied: starlette<2.0,>=1.0.1 in c:\users\waris\appdata\roaming\python\python313\site-packages (from gradio[mcp]) (1.3.1)
# Requirement already satisfied: tomlkit<0.15.0,>=0.12.0 in c:\programdata\anaconda3\lib\site-packages (from gradio[mcp]) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\programdata\anaconda3\lib\site-packages (from gradio[mcp]) (0.20.0)
# Requirement already satisfied: typing-extensions~=4.0 in c:\programdata\anaconda3\lib\site-packages (from gradio[mcp]) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\waris\appdata\roaming\python\python313\site-packages (from gradio[mcp]) (0.49.0)
# Requirement already satisfied: mcp<2.0.0,>=1.21.0 in c:\users\waris\appdata\roaming\python\python313\site-packages (from gradio[mcp]) (1.26.0)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\lib\site-packages (from gradio-client==2.5.0->gradio[mcp]) (2025.10.0)
# Requirement already satisfied: idna>=2.8 in c:\programdata\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio[mcp]) (3.11)
# Requirement already satisfied: sniffio>=1.1 in c:\programdata\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio[mcp]) (1.3.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\programdata\anaconda3\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio[mcp]) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\waris\appdata\roaming\python\python313\site-packages (from fastapi<1.0,>=0.115.2->gradio[mcp]) (0.0.4)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio[mcp]) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio[mcp]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio[mcp]) (0.16.0)
# Requirement already satisfied: click>=8.4.0 in c:\users\waris\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=1.2.0->gradio[mcp]) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.2.0->gradio[mcp]) (3.20.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\users\waris\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=1.2.0->gradio[mcp]) (1.5.1)
# Requirement already satisfied: tqdm>=4.42.1 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.2.0->gradio[mcp]) (4.67.1)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\waris\appdata\roaming\python\python313\site-packages (from mcp<2.0.0,>=1.21.0->gradio[mcp]) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\programdata\anaconda3\lib\site-packages (from mcp<2.0.0,>=1.21.0->gradio[mcp]) (4.25.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\waris\appdata\roaming\python\python313\site-packages (from mcp<2.0.0,>=1.21.0->gradio[mcp]) (2.10.1)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\waris\appdata\roaming\python\python313\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.21.0->gradio[mcp]) (2.13.0)
# Requirement already satisfied: pywin32>=310 in c:\programdata\anaconda3\lib\site-packages (from mcp<2.0.0,>=1.21.0->gradio[mcp]) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\waris\appdata\roaming\python\python313\site-packages (from mcp<2.0.0,>=1.21.0->gradio[mcp]) (3.4.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas<4.0,>=1.0->gradio[mcp]) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas<4.0,>=1.0->gradio[mcp]) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<=3.0,>=2.0->gradio[mcp]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\waris\appdata\roaming\python\python313\site-packages (from pydantic<=3.0,>=2.0->gradio[mcp]) (2.41.5)
# Requirement already satisfied: shellingham>=1.3.0 in c:\programdata\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio[mcp]) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\programdata\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio[mcp]) (14.2.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click>=8.4.0->huggingface-hub<2.0,>=1.2.0->gradio[mcp]) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.21.0->gradio[mcp]) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.21.0->gradio[mcp]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.21.0->gradio[mcp]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.21.0->gradio[mcp]) (0.28.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\waris\appdata\roaming\python\python313\site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.21.0->gradio[mcp]) (1.2.2)
# Requirement already satisfied: cryptography>=3.4.0 in c:\programdata\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.21.0->gradio[mcp]) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.21.0->gradio[mcp]) (2.0.0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.21.0->gradio[mcp]) (2.23)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio[mcp]) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio[mcp]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio[mcp]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\programdata\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio[mcp]) (0.1.2)

# %%
# tutor_mcp_server.py
"""AI Tutor MCP Toolkit
======================

A compact server that exposes **four** powerful learning‑oriented tools via the
Model‑Context‑Protocol (MCP). All functions are OpenAI‑powered, and most stream
partial tokens for low‑latency UX.
"""

import os
import io
from typing import Generator, List
import gradio as gr
from openai import OpenAI
from dotenv import load_dotenv

# -----------------------------------------------------------------------------
# Environment & OpenAI client setup
# -----------------------------------------------------------------------------
load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY")
if not openai_api_key:
    raise ValueError("OPENAI_API_KEY not found in .env file. Server cannot start.")

client = OpenAI(api_key = openai_api_key)
MODEL_NAME = "gpt-4o-mini"

# %% [markdown]
# Available MCP tools
# -------------------
# 1. **`explain_concept`** – Stream an explanation of any concept at a chosen
#    complexity level (1 = kid‑friendly … 5 = expert).
# 2. **`summarize_text`** – Stream a concise summary of long text, controllable
#    with a *compression_ratio*.
# 3. **`generate_flashcards`** – Produce study flashcards (Q/A pairs) for rapid
#    review of a topic.
# 4. **`quiz_me`** – Stream an interactive quiz on a topic; reveals answers after
#    questions.

# %%
# Let's define the mapping from integers (1-5) to explanation levels
EXPLANATION_LEVELS = {
    1: "like I'm 5 years old",
    2: "like I'm 10 years old",
    3: "like a high school student",
    4: "like a college student",
    5: "like an expert in the field",
}

# %%
# In the MCP Server.ipynb file, update the docstring as shown below

def explain_concept(question: str, level: int) -> Generator[str, None, None]:
    """Stream an explanation of *question* at the requested *level* (1‑5). If 1, explanation would be like we are talking to a 5 year old and if 5, explanation would be technical and complex."""
    if not question.strip():
        yield "Error: question cannot be blank."
        return

    level_desc = EXPLANATION_LEVELS.get(level, "clearly and concisely")
    system_prompt = "You are a helpful AI Tutor. Explain the following concept " f"{level_desc}."
    _stream = client.chat.completions.create(
        model=MODEL_NAME,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": question},
        ],
        stream=True,
        temperature=0.7,
    )
    partial = ""
    for chunk in _stream:
        delta = getattr(chunk.choices[0].delta, "content", None)
        if delta:
            partial += delta
            yield partial

# %%
# Define the explain concept function
def explain_concept(question: str, level: int) -> Generator[str, None, None]:
    """Stream an explanation of *question* at the requested *level* (1‑5)."""
    if not question.strip():
        yield "Error: question cannot be blank."
        return

    level_desc = EXPLANATION_LEVELS.get(level, "clearly and concisely")
    system_prompt = "You are a helpful AI Tutor. Explain the following concept " f"{level_desc}."
    _stream = client.chat.completions.create(
        model = MODEL_NAME,
        messages = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": question},
        ],
        stream = True,
        temperature = 0.7,
    )
    partial = ""
    for chunk in _stream:
        delta = getattr(chunk.choices[0].delta, "content", None)
        if delta:
            partial += delta
            yield partial

# %%
# Define the summarize text function
def summarize_text(text: str, compression_ratio: float = 0.3) -> Generator[str, None, None]:
    """Stream a summary of *text* compressed to roughly *compression_ratio* length.

    *compression_ratio* should be between 0.1 and 0.8.
    """
    if not text.strip():
        yield "Error: text cannot be blank."
        return
    ratio = max(0.1, min(compression_ratio, 0.8))
    system_prompt = (
        "You are a world‑class summarizer. Reduce the following text to about "
        f"{int(ratio*100)}% of its original length while preserving key ideas."
    )
    _stream = client.chat.completions.create(
        model = MODEL_NAME,
        messages = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": text},
        ],
        stream = True,
        temperature = 0.5,
    )
    partial = ""
    for chunk in _stream:
        delta = getattr(chunk.choices[0].delta, "content", None)
        if delta:
            partial += delta
            yield partial

# %%
# Define the generate flashcards function
def generate_flashcards(topic: str, num_cards: int = 5) -> Generator[str, None, None]:
    """Stream *num_cards* Q/A flashcards for *topic* in JSON lines format."""
    if num_cards < 1 or num_cards > 20:
        yield "Error: num_cards must be between 1 and 20."
        return
    if not topic.strip():
        yield "Error: topic cannot be blank."
        return

    system_prompt = (
        "You are an AI that generates study flashcards. "
        'Return each flashcard on its own line as JSON: {"q": <question>, "a": <answer>}'
    )
    user_prompt = f"Create {num_cards} flashcards about {topic}."

    _stream = client.chat.completions.create(
        model = MODEL_NAME,
        messages = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt},
        ],
        stream = True,
        temperature = 0.8,
    )
    partial = ""
    for chunk in _stream:
        delta = getattr(chunk.choices[0].delta, "content", None)
        if delta:
            partial += delta
            yield partial

# %%
# Define the Quiz Me function

def quiz_me(topic: str, level: int = 3, num_questions: int = 5) -> Generator[str, None, None]:
    """Stream a quiz with numbered Qs then reveal answers after all questions."""
    if num_questions < 1 or num_questions > 15:
        yield "Error: num_questions must be between 1 and 15."
        return
    if not topic.strip():
        yield "Error: topic cannot be blank."
        return

    level_desc = EXPLANATION_LEVELS.get(level, "at an intermediate level")
    system_prompt = (
        "You are an AI quiz master. Generate a quiz of multiple‑choice questions "
        f"about {topic} {level_desc}. Number the questions. After listing all Qs, "
        "add an \nANSWER KEY section with the correct options."
    )

    _stream = client.chat.completions.create(
        model = MODEL_NAME,
        messages = [{"role": "system", "content": system_prompt}],
        stream = True,
        temperature = 0.7,
    )
    partial = ""
    for chunk in _stream:
        delta = getattr(chunk.choices[0].delta, "content", None)
        if delta:
            partial += delta
            yield partial

# %% [markdown]
# # TASK 4B. LAUNCH THE GRADIO MCP SERVER

# %%
def build_demo():
    with gr.Blocks() as demo:
        gr.Markdown("# AI Tutor MCP Toolkit – Demo Console")
        with gr.Tab("Explain Concept"):
            q = gr.Textbox(label="Concept / Question")
            lvl = gr.Slider(1, 5, value=3, step=1, label="Explanation Level")
            out1 = gr.Markdown()
            gr.Button("Explain").click(explain_concept, inputs=[q, lvl], outputs=out1)
        with gr.Tab("Summarize Text"):
            txt = gr.Textbox(lines=8, label="Long Text")
            ratio = gr.Slider(0.1, 0.8, value=0.3, step=0.05, label="Compression Ratio")
            out2 = gr.Markdown()
            gr.Button("Summarize").click(summarize_text, inputs=[txt, ratio], outputs=out2)
        with gr.Tab("Flashcards"):
            topic_fc = gr.Textbox(label="Topic")
            n_fc = gr.Slider(1, 20, value=5, step=1, label="# Cards")
            out3 = gr.Markdown()
            gr.Button("Generate").click(generate_flashcards, inputs=[topic_fc, n_fc], outputs=out3)
        with gr.Tab("Quiz Me"):
            topic_q = gr.Textbox(label="Topic")
            lvl_q = gr.Slider(1, 5, value=3, step=1, label="Difficulty Level")
            n_q = gr.Slider(1, 15, value=5, step=1, label="# Questions")
            out4 = gr.Markdown()
            gr.Button("Start Quiz").click(quiz_me, inputs=[topic_q, lvl_q, n_q], outputs=out4)
    return demo


if __name__ == "__main__":
    print("Starting AI Tutor MCP Toolkit on port 7860…")
    build_demo().launch(server_name = "0.0.0.0", mcp_server = True)
# --- END OF FILE ---
# Out:
# Starting AI Tutor MCP Toolkit on port 7860…
# ERROR:    [Errno 10048] error while attempting to bind on address ('0.0.0.0', 7860): [winerror 10048] only one usage of each socket address (protocol/network address/port) is normally permitted
# ERROR:    Traceback (most recent call last):
#   File "C:\Users\waris\AppData\Roaming\Python\Python313\site-packages\starlette\routing.py", line 638, in lifespan
#     async with self.lifespan_context(app) as maybe_state:
#                ~~~~~~~~~~~~~~~~~~~~~^^^^^
#   File "C:\ProgramData\anaconda3\Lib\contextlib.py", line 214, in __aenter__
#     return await anext(self.gen)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\waris\AppData\Roaming\Python\Python313\site-packages\fastapi\routing.py", line 232, in merged_lifespan
#     async with original_context(app) as maybe_original_state:
#                ~~~~~~~~~~~~~~~~^^^^^
#   File "C:\ProgramData\anaconda3\Lib\contextlib.py", line 214, in __aenter__
#     return await anext(self.gen)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\waris\AppData\Roaming\Python\Python313\site-packages\gradio\route_utils.py", line 1063, in _handler
#     state = await stack.enter_async_context(user_lifespan(app))
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\ProgramData\anaconda3\Lib\contextlib.py", line 668, in enter_async_context
#     result = await _enter(cm)
#              ^^^^^^^^^^^^^^^^
#   File "C:\ProgramData\anaconda3\Lib\contextlib.py", line 214, in __aenter__
#     return await anext(self.gen)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\waris\AppData\Roaming\Python\Python313\site-packages\gradio\routes.py", line 341, in _lifespan
#     await stack.enter_async_context(
#         blocks.mcp_server_obj.lifespan(app)
#     )
#   File "C:\ProgramData\anaconda3\Lib\contextlib.py", line 668, in enter_async_context
#     result = await _enter(cm)
#              ^^^^^^^^^^^^^^^^
#   File "C:\ProgramData\anaconda3\Lib\contextlib.py", line 214, in __aenter__
#     return await anext(self.gen)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\waris\AppData\Roaming\Python\Python313\site-packages\gradio\mcp.py", line 436, in lifespan
#     async with manager.run():
#                ~~~~~~~~~~~^^
#   File "C:\ProgramData\anaconda3\Lib\contextlib.py", line 214, in __aenter__
#     return await anext(self.gen)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\waris\AppData\Roaming\Python\Python313\site-packages\mcp\server\streamable_http_manager.py", line 107, in run
#     raise RuntimeError(
#     ...<2 lines>...
#     )
# RuntimeError: StreamableHTTPSessionManager .run() can only be called once per instance. Create a new instance if you need to run again.
#
# ERROR:    Application startup failed. Exiting.

# %%
# Out:
# Starting AI Tutor MCP Toolkit on port 7860…
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 36
#      34 if __name__ == "__main__":
#      35     print("Starting AI Tutor MCP Toolkit on port 7860…")
# ---> 36     build_demo().launch(server_name = "0.0.0.0", mcp_server = True)
#
# Cell In[10], line 14, in build_demo()
#      12     lang = gr.Textbox(label = "Language")
#      13     out2 = gr.Markdown()
# ---> 14     gr.Button("Explain").click(explain_concept_in_language, inputs = [q, lvl, lang], outputs = out2)
#      15 with gr.Tab("Summarize Text"):
#      16     txt = gr.Textbox(lines = 8, label = "Long Text")
#
# NameError: name 'explain_concept_in_language' is not defined

# %%
def explain_concept_in_language(question: str, level: int, language: str) -> Generator[str, None, None]:
    """Stream an explanation of *question* at the requested *level* (1‑5) in the specified *language*. 
    Need: question, level, language"""

    if not question.strip():
        yield "Error: question cannot be blank."
        return

    level_desc = EXPLANATION_LEVELS.get(level, "clearly and concisely")
    system_prompt = "You are a helpful AI Tutor. Explain the following concept " f"{level_desc} in the following language: {language}"
    _stream = client.chat.completions.create(
        model = MODEL_NAME,
        messages = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": question},
        ],
        stream = True,
        temperature =0.7,
    ) 
    partial = ""
    for chunk in _stream:
        delta = getattr(chunk.choices[0].delta, "content", None)
        if delta:
            partial += delta
            yield partial

def build_demo():
    with gr.Blocks() as demo:
        gr.Markdown("# AI Tutor MCP Toolkit – Demo Console")
        with gr.Tab("Explain Concept"):
            q = gr.Textbox(label = "Concept / Question")
            lvl = gr.Slider(1, 5, value = 3, step = 1, label = "Explanation Level")
            out1 = gr.Markdown()
            gr.Button("Explain").click(explain_concept, inputs = [q, lvl], outputs = out1)
        with gr.Tab("Explain Concept in Language"):
            q = gr.Textbox(label = "Concept / Question")
            lvl = gr.Slider(1, 5, value = 3, step = 1, label = "Explanation Level")
            lang = gr.Textbox(label = "Language")
            out2 = gr.Markdown()
            gr.Button("Explain").click(explain_concept_in_language, inputs = [q, lvl, lang], outputs = out2)
        with gr.Tab("Summarize Text"):
            txt = gr.Textbox(lines = 8, label = "Long Text")
            ratio = gr.Slider(0.1, 0.8, value = 0.3, step = 0.05, label = "Compression Ratio")
            out3 = gr.Markdown()
            gr.Button("Summarize").click(summarize_text, inputs=[txt, ratio], outputs = out3)
        with gr.Tab("Flashcards"):
            topic_fc = gr.Textbox(label = "Topic")
            n_fc = gr.Slider(1, 20, value = 5, step = 1, label = "# Cards")
            out4 = gr.Markdown()
            gr.Button("Generate").click(generate_flashcards, inputs = [topic_fc, n_fc], outputs = out4)
        with gr.Tab("Quiz Me"):
            topic_q = gr.Textbox(label = "Topic")
            lvl_q = gr.Slider(1, 5, value = 3, step = 1, label = "Difficulty Level")
            n_q = gr.Slider(1, 15, value = 5, step = 1, label = "# Questions")
            out5 = gr.Markdown()
            gr.Button("Start Quiz").click(quiz_me, inputs = [topic_q, lvl_q, n_q], outputs = out5)
    return demo


if __name__ == "__main__":
    print("Starting AI Tutor MCP Toolkit on port 7860…")
    build_demo().launch(server_name = "0.0.0.0", mcp_server = True)
# Out:
# Starting AI Tutor MCP Toolkit on port 7860…
# * Running on local URL:  http://0.0.0.0:7860
# * To create a public link, set `share=True` in `launch()`.
#
# 🔨 Launching MCP server:
# * Streamable HTTP URL: http://localhost:7860/gradio_api/mcp/
# <div><iframe src="http://localhost:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
